# %% [markdown]
# <a href="https://colab.research.google.com/github/GitHubrenu/ProgrammingAssignment2/blob/master/Survey_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-b6fa67df-9efd-4375-8867-2d109470a5a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b6fa67df-9efd-4375-8867-2d109470a5a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving survey_results_public.csv to survey_results_public (3).csv

# %%
import pandas as pd

# %%
 import io
dataf = pd.read_csv(io.BytesIO(data_to_load['survey_results_public.csv']))

# %%
dataf
# Out:
#        Respondent  ...                  SurveyEase
# 0               1  ...  Neither easy nor difficult
# 1               2  ...  Neither easy nor difficult
# 2               3  ...  Neither easy nor difficult
# 3               4  ...                        Easy
# 4               5  ...                        Easy
# ...           ...  ...                         ...
# 88878       88377  ...                        Easy
# 88879       88601  ...                         NaN
# 88880       88802  ...                         NaN
# 88881       88816  ...                         NaN
# 88882       88863  ...                        Easy
#
# [88883 rows x 85 columns]

# %%
dataf.info
# Out:
# <bound method DataFrame.info of        Respondent  ...                  SurveyEase
# 0               1  ...  Neither easy nor difficult
# 1               2  ...  Neither easy nor difficult
# 2               3  ...  Neither easy nor difficult
# 3               4  ...                        Easy
# 4               5  ...                        Easy
# ...           ...  ...                         ...
# 88878       88377  ...                        Easy
# 88879       88601  ...                         NaN
# 88880       88802  ...                         NaN
# 88881       88816  ...                         NaN
# 88882       88863  ...                        Easy
#
# [88883 rows x 85 columns]>

# %%
dataf.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
 count=dataf["LanguageWorkedWith"].value_counts() 
count.head(1)
# Out:
# HTML/CSS;JavaScript;PHP;SQL    1483
# Name: LanguageWorkedWith, dtype: int64

# %%
 import matplotlib.pyplot as plt
group=df['WorkRemote'].value_counts()
plt.pie(group,labels=group,autopct='%.1f%%')
plt.legend(group,loc="upper right")
plt.axis('equal')
plt.show()

# %%
 gender=df['Gender'].value_counts()
result=gender.head(2)
label=['Men','Female']
colors=['yellowgreen','pink']
plt.pie(result,labels=label,autopct="%.1f%%",shadow=True,colors=colors)
plt.legend(label)
plt.axis('equal')
plt.show()

# %%
 result=df['DevType'].value_counts()
print('In demand developers:',)
result.head(1)
# Out:
# In demand developers:
# Developer, full-stack    3451
# Name: DevType, dtype: int64

# %%
 result=df["LanguageDesireNextYear"].value_counts()
print('langauge programmer is going to learn in next year:')
result.head(3)
# Out:
# langauge programmer is going to learn in next year:
# Python                            499
# HTML/CSS;JavaScript               291
# HTML/CSS;JavaScript;TypeScript    288
# Name: LanguageDesireNextYear, dtype: int64

# %%
 result=df['Country'].value_counts()
print(" top 3 country programmer take part in survey:")
result.head(3)
# Out:
#  top 3 country programmer take part in survey:
# United States    8641
# India            3744
# Germany          2410
# Name: Country, dtype: int64
